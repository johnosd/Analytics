# %% [markdown]
# ---
# **Autor**: Profs. Dino Magri e João Nogueira
#
# **Contato**: `professor.dinomagri@gmail.com`, `joaonogueira@fisica.ufc.br`
#
# **Licença deste notebook**:
# <br>
# <img align="left" width="80" src="https://licensebuttons.net/l/by/3.0/88x31.png" />
#
# <br>
# <br>
#
# [Clique aqui para saber mais sobre a licença CC BY v4.0](https://creativecommons.org/licenses/by/4.0/legalcode.pt)
#
#
# ---

# %% [markdown]
# ## Pandas Profiling
#
# Por fim, iremos instalar uma biblioteca que irá apresentar uma visão geral da nossa base de dados.
#
# https://pandas-profiling.github.io/pandas-profiling/docs/master/rtd/

# %%
# !pip install pandas-profiling==2.7.1

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from pandas_profiling import ProfileReport

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/My Drive/projeto-ia-datasets/preco_casas_final.csv', sep=';')

# %%
profile = ProfileReport(df, title='Dataframe Profile Report')

# %%
# Utilize o comando abaixo para visualizar o relatório que foi gerado.
# Pode levar alguns minutos para gerar o relatório.
profile

# %%
# Caso não seja possível visualizar o relatório aqui, salve em HTML
# Pode levar alguns minutos para gerar o relatório.
profile.to_file('/content/drive/My Drive/projeto-ia-datasets/relatorio_conjunto_dados.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
